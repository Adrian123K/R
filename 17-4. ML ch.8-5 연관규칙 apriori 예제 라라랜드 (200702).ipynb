# %% [markdown]
# ## <b>■ apriori 알고리즘 예제 3  ( 영화 라라랜드 )</b>

# %%
# 1.  라라랜드 데이터를 로드한다.  
library(KoNLP)
library(wordcloud)

lala <- read.csv('라라랜드.csv', header=T, stringsAsFactors = F)

# 2. 영화평점이 9점이상은 긍정변수넣고 2점 이하는 부정변수에 넣는다 
lala_positive <- lala[lala$score>=9,c('content')]
lala_negative <- lala[lala$score<=2,c('content')]

head(lala_positive)
head(lala_negative)

# 3. 긍정게시판 변수에서 명사만 추출하고 데이터 정제 작업을 한다.

po <- sapply(lala_positive, extractNoun, USE.NAMES=F)
po2 <- unlist(po)
po2 <- Filter(function(x){nchar(x)>=2},po2)
po3 <- gsub('\\d+','',po2)
po3 <- gsub('관람객','',po3)
po3 <- gsub('평점', '', po3)
po3 <- gsub('영화', '', po3)
po3 <- gsub('진짜', '', po3)
po3 <- gsub('완전', '', po3)
po3 <- gsub('시간', '', po3)
po3 <- gsub('올해', '', po3)
po3 <- gsub('장면', '', po3)
po3 <- gsub('남자', '', po3)
po3 <- gsub('여자', '', po3)
po3 <- gsub('만큼', '', po3)
po3 <- gsub('니가', '', po3)
po3 <- gsub('년대', '', po3)
po3 <- gsub('옆사람', '', po3)
po3 <- gsub('들이', '', po3)
po3 <- gsub('저녁', '', po3)

write(unlist(po3), 'lala_positive.txt')
po4 <- read.table('lala_positive.txt')
po_wordcount <- table(po4)

# 4. 라라랜드 영화에 부정적인 평가 게시글들 명사로 변경하고 정재 작업을 수행한다. 

ne <- sapply(lala_negative, extractNoun, USE.NAMES=F)
ne2 <- unlist(ne)
ne2 <- Filter(function(x){nchar(x)>=2},ne2)
ne3 <- gsub('\\d+','',ne2)
ne3 <- gsub('관람객','',ne3)
ne3 <- gsub('평점', '', ne3)
ne3 <- gsub('영화', '', ne3)
ne3 <- gsub('진짜', '', ne3)
ne3 <- gsub('완전', '', ne3)
ne3 <- gsub('시간', '', ne3)
ne3 <- gsub('올해', '', ne3)
ne3 <- gsub('장면', '', ne3)
ne3 <- gsub('남자', '', ne3)
ne3 <- gsub('여자', '', ne3)
ne3 <- gsub('만큼', '', ne3)
ne3 <- gsub('니가', '', ne3)
ne3 <- gsub('년대', '', ne3)
ne3 <- gsub('옆사람', '', ne3)
ne3 <- gsub('들이', '', ne3)
ne3 <- gsub('저녁', '', ne3)

write(unlist(ne3), 'lala_negative.txt')

ne4 <- read.table('lala_negative.txt')
ne_wordcount <- table(ne4)

# 5. 긍정 단어와 부정단어를 각각 워드 클라우드로 그려서 한 화면에 출력한다. 
graphics.off()
palete <- brewer.pal(9,'Set1')
par(new=T, mfrow=c(1,2))

wordcloud(names(po_wordcount), freq=po_wordcount, scale=c(3,1), rot.per=0.1, random.order = F,
          random.color = T, col=rainbow(15))
title(main='라라랜드의 긍정적인 평가', col.main='blue')

wordcloud(names(ne_wordcount), freq=ne_wordcount, scale=c(3,1), rot.per=0.1, random.order = F,
          random.color = T, col=rainbow(15))
title(main='라라랜드의 부정적인 평가', col.main='red')
# Out:
# Warning message:
# "package 'KoNLP' was built under R version 3.6.3"Checking user defined dictionary!
#
# Warning message:
# "package 'wordcloud' was built under R version 3.6.3"Loading required package: RColorBrewer
# [1] "39 그래도 우리 잘 해냈지   39 라고 말하는 듯한 마지막 눈빛교환이 잊혀지질 않는다"
# [2] "와  그냥 감탄밖엔 안 나온다  영상미며 음악이며  조폭  건달  검사  신파 좋아하고 실험을 꺼리는 한국의 기성 영화인들 반성해라  이제 겨우 두 편 만든 신인감독이 이 정도다"
# [3] "꿈과 사랑  우리는 항상 성공인지 실패인지 평가만 해왔다  하지만 라라랜드는 말해준다    34 봐  꿈과 사랑  그 흔들리는 파도가 얼마나 아름다운지  34"
# [4] "내일 죽으면 오늘 보러 갈만한 영화"
# [5] "마지막 회상신에서 처음과 달리 키스신으로 스토리시작될때 진짜 소리지를뻔"
# [6] "마지막 10분 동안 휘몰아치는 감정의 소용돌이에 결국 눈물이 흐르게 만드는 마법같은 영화  노트북 때에도 그렇고 라이언 고슬링은 이런 역할에 도가 튼 것 같다"
# [1] "관람객       저만 재미없나봐요"
# [2] "관람객       제스타일의영화가아니였습니다"
# [3] "관람객       저랑은 안맞는영화인것같네요"
# [4] "관람객       나는 개인적으로 별로 재미 없었어요"
# [5] "나만재미없냐 솔직히말해봐라"
# [6] "관람객       어     왜 이게 인생영화라는건지 1도 모르겠어영   노래도 좋긴한데 전체적으로 쫌 지겨운느낌"
# Warning message in par(new = T, mfrow = c(1, 2)):
# "플랏없이 par(new=TRUE)를 호출합니다"Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "해피엔딩 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "좋았습니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "봤습니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "엠마스톤 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌어요 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "훌륭 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "누구 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "라이언고슬링 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "선택 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "정도 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "분위기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "연주 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "대사 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "상상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "간만 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "따뜻 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "추천합니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "구성 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "무엇 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "크리스마스 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "하기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이해 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "자체 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "남녀 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "씁쓸 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "추억 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "고민 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "관객 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "엠마 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "보고 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "뭔가 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "자신 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "만족 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "선율 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이유 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "명작 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "모두 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "청춘 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "울컥 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "각자 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "라라랜 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "사이 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "조화 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "라라랜드는 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "성공 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "소름 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "응원 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "해지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "박수 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "세상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "후반 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "소장 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "감탄 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이후 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "감사 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "그때 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "전개 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "정말 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "희망 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "당신 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "취향 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "보고싶 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "로맨틱 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "신선 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "어른 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "의미 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이별 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌었어요 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "근데 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "때문 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "아름다운 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "전체 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "포기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "노력 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "아름다움 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "아름답 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "진심 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "과거 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "멜로디 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "소리 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "안보 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "호불호가 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "감상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "마무리 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "천재 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "판타지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "교환 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "대단 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "인상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌고 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "사운드 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌었어 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "강추합니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "귓가 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "그것 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "동안 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "머릿속 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "연애 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "화려 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "오디션 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "요소 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "호강 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "가지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "다시한번 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "부족 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "연말 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "잘봤습니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재즈음악 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "평생 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "화면 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "노트북 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "다미 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "반전 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "위로 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "자리 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "크레딧 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "혼자 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "겨울 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "경험 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "내인 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "연기력 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "과정 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "누군가 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "다음 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "비현실적 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "선물 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "스톤 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "애잔 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "오랫만 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "장르 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌어 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "집중 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "결혼 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "단순 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "사실 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "여주인공 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "연출력 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이번 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "가시 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "감동적 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "보시 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "시절 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "회상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "계속 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "라라랜드를 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "애틋 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "의상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "좋은 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "진정 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "최고입니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "표정 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "감정이입 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "강추 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "덕분 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "보길 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "심장 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "아쉬움 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "압권 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "얘기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "어디 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "유쾌 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이는 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "자기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "진부 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "한마디 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "한번더 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "한번쯤 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "같습니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "개봉 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "고전 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "모든것이 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "세바스찬 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "소중 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "스크린 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "어제 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "역대 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이거 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "첫사랑 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "그녀 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "다운 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "달콤 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "여주 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "잘봤습니다 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌는 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "좋습니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "좌절 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "찬란 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "키스 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "가득 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "가족 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "가치 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "나중 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "두번봐도 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "라라랜드가 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "몽환적 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "상황 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "자극 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "그림 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "도전 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "미래 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "실패 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "아름다 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "엠마스톤이 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "인연 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "클래식 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "한영 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "근래 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "댄스 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "도시 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "상영 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "아름다웠 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "아이맥스 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "전반 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "중요 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "하루 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "꼭보세 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "남주 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "둘다 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "만약 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "머리 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "메세지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "베스트 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "웃음 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "위플래쉬 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이를 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "있었 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌습니다 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "젊은이 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "중반 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "차젤레 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "최고였 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "해피 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "감사합니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "굿굿 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "꼭보세요 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "압도 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "없었 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "예상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "용기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "최고의 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "탭댄스 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "특별 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "한국 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "한동안 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "가사 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "같았 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "나름 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "느낌 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "뮤직 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "반복 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "비슷 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "섬세 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "순수 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "예술가 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "울었 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "음향 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "카메라 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "타협 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "탄탄 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "평범 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "할거 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "고슬링이 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "다시보고싶은 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "드라마 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "등극 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "무한 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "성장 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "세계 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "슬프 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "시퀀스 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "쓸쓸 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "연극 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "우리나라 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이걸 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "잊혀지질 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "자연 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌네요 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "적절 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "전달 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "제목 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "최근 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "평소 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "한데 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "레미제라블 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "많은 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "무대 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "보기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "분명 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "스타일 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "심야 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "옛날 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "위플래시 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "이것 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "재밌다 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "좋은영 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "주제 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "진행 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "추가 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "가는줄 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "가능 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "감미 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "고전적 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "꿀잼 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "다행 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "달콤한 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "등등 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "라라랜드로 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "라인 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "메시지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "별점 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "불구 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "생애 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "설명 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "세련 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "연속 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "유치 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "존재 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "지금 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "첫장 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "캐릭터 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "하루종일 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "합니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "굳굳 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "되었 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "마주 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "먹먹한 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "멜로 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# "목소리 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(po_wordcount), freq = po_wordcount, scale = c(3, :
# ...
# "년후 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "눈빛 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "답답 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "대실 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "대중 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "댓글알바 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "덕분 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "돈낭비 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "돈아깝다 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "돈주고 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "라라랜드 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "랜드 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "레미제라블 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "마법 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "마이너스 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "막판 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "많은 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "머리 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "메세지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "메시지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "멜로 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "명작 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "무엇 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "뭔지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "반개 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "반대 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "발단 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "별루 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "본인 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "비긴어게인에 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "비현실적 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "살다살다 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "상상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "새끼 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "선율 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "소재 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "숙면 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "순간 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "스토 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "시도 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "식상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "실패 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "심야 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "씁쓸 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "아름다운 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "아이 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "안남기는데 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "안볼 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "알바 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "알았 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "액션 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "얘기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "어색 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "얼굴 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "얼마 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "엄청 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "없었 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "없었습니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "엠마스톤은 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "여배우 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "여운 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "연기력 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "연인 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "예고편 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "오글거리고 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "오프닝 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "와이프 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "완벽 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "왜이 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "왤케 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "외국 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "위플래쉬 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "의심 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "이게왜 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "이기 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "이딴 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "이딴걸 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "이런거 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "이름 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "이유 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "인간 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "인성 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "자랑 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "자막 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "재미없 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "재밌게 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "재밌는지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "재즈음악 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "점정도 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "제로 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "조건 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "조절 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "존재 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "졸작 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "주변 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "지루합니 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "진행 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "찝찝한 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "참고 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "참신 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "천문대 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "칭찬 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "키스 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "판타지 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "평범 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "평생 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "포장 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "표현 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "한국 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "헐리우드 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "확인 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "환상 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "환승 could not be fit on page. It will not be plotted."Warning message in wordcloud(names(ne_wordcount), freq = ne_wordcount, scale = c(3, :
# "후회 could not be fit on page. It will not be plotted."

# %% [markdown]
# ### ※문제282. (오늘의 마지막 문제) 라라랜드의 긍정적 평가 게시판의 글들을 명사만추출한 다음 단어들간의 연관관계를 출력하시오

# %%
#답 :
library(KoNLP)
library(wordcloud)

install.packages("tm")
library(tm)
library(stringr)
library(arules)

#2. 명사 추출하는 코드 
lala_positive <- sapply(lala_positive, extractNoun, USE.NAMES=F)
head(lala_positive)

#3. unlist 로 변환한후에 철자가 2개이상이고 5개 이하인것만 추출 
c <- unlist(lala_positive)
lala_positive2 <- Filter(function(x) { nchar(x) >= 2 & nchar(x) <= 5 }  , c)

#4. 데이터 정제작업( 분석하기에 너무 많이 나오는 단어를 삭제하는 작업 )
# 숫자제거 
lala_positive2 <- gsub('\\d+','',lala_positive2)
lala_positive2 <- gsub('관람객','',lala_positive2)
lala_positive2 <- gsub('평점', '', lala_positive2)
lala_positive2 <- gsub('영화', '', lala_positive2)
lala_positive2 <- gsub('진짜', '', lala_positive2)
lala_positive2 <- gsub('완전', '', lala_positive2)
lala_positive2 <- gsub('시간', '', lala_positive2)
lala_positive2 <- gsub('올해', '', lala_positive2)
lala_positive2 <- gsub('장면', '', lala_positive2)
lala_positive2 <- gsub('남자', '', lala_positive2)
lala_positive2 <- gsub('여자', '', lala_positive2)
lala_positive2 <- gsub('만큼', '', lala_positive2)
lala_positive2 <- gsub('니가', '', lala_positive2)
lala_positive2 <- gsub('년대', '', lala_positive2)
lala_positive2 <- gsub('옆사람', '', lala_positive2)
lala_positive2 <- gsub('들이', '', lala_positive2)
lala_positive2 <- gsub('저녁', '', lala_positive2)
lala_positive2 <- gsub('영화', '', lala_positive2)
lala_positive2 

#5. 한글이 아닌 데이터를 제거하는 작업 
res <- str_replace_all(lala_positive2, "[^[:alpha:]]","")

#6.  ""  데이터 제거하는 작업 
res <- res[res != ""] 

#7. 단어와 그 건수를 출력하는 작업 
wordcount <- table(res)
wordcount2 <- sort( table(res), decreasing=T)

#8. 단어의 건수가 100 보다 큰것만 필터링 
keyword <- names( wordcount2[wordcount2>100] )
length(lala_positive)

#9. 아프리오리 분석을 위해서 표형태로 만드는 작업 
contents <- c()
for(i in 1:length(lala_positive)) { 
  inter <- intersect(lala_positive[[i]] , keyword)
  contents <- rbind(contents ,table(inter)[keyword])
}

#10. 표의 컬럼명에 단어가 들어가게한다.
colnames(contents) <- keyword

#11. na 를 숫자 0 으로 변경한다. 
contents[which(is.na(contents))] <- 0 
dim(lala_positive)

#12. 아프리오리 데이터 분석
detach(package:tm, unload=T)
library(arules) 

rules_lala <- apriori(contents , parameter = list(supp = 0.007 , conf = 0.3 , target = "rules"))
rules_lala 

inspect(sort(rules_lala))

b2 <- t(as.matrix(contents)) %*% as.matrix(contents) 
b2

b2.w <- b2 - diag(diag(b2))
b2.w

library(sna)
library(rgl)

#rownames(b2.w) 
#colnames(b2.w) 

gplot(b2.w , displaylabel=T , vertex.cex=sqrt(diag(b2)) , vertex.col = "green" , 
      edge.col="blue" , boxed.labels=F , arrowhead.cex = .3 , label.pos = 3 , edge.lwd = b2.w*2)

#visualization

gplot(b2.w , displaylabel=T , vertex.cex=sqrt(diag(b2)) , vertex.col = "pink" , 
      edge.col="light green" , boxed.labels=F , 
      arrowhead.cex = .3 , label.pos = 3 , edge.lwd = b2.w*2)
